# %%
import time
import os
import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
import mediapipe as mp
import random

# %% [markdown]
# # **Dataset Collection Code**
#
# Purpose:
# This code captures and stores labeled hand gesture images for Arabic Sign Language letters using a webcam.
# It organizes the data into class-specific folders and ensures consistent image size and quality for training.

# %%
# ---------------- User Settings ----------------
DATA_DIR = './data_32_letters'   # Dataset root directory (will contain 32 subfolders)
dataset_size = 80                # Number of images per class (adjustable)
delay_between_saves = 0.2        # Seconds between consecutive saves
resize_to = (224, 224)           # Saved image resolution
mirror_preview = False           # False => non-mirrored preview by default
bottom_text_height = 120         # Height of the bottom text/info area
mask_preview_size = (120, 120)   # Size of the small mask preview
camera_index = 0                 # Camera index
min_contour_area = 2000          # Minimum contour area threshold for saving
# ------------------------------------------------

# List of 32 classes (transliteration, arabic_label)
labels = [
    ("alif", "ا"),
    ("baa", "ب"),
    ("taa", "ت"),
    ("thaa", "ث"),
    ("jeem", "ج"),
    ("haa", "ح"),
    ("khaa", "خ"),
    ("dal", "د"),
    ("dhal", "ذ"),
    ("raa", "ر"),
    ("zay", "ز"),
    ("seen", "س"),
    ("sheen", "ش"),
    ("saad", "ص"),
    ("daad", "ض"),
    ("taa_h", "ط"),
    ("zaa_h", "ظ"),
    ("ayn", "ع"),
    ("ghayn", "غ"),
    ("faa", "ف"),
    ("qaf", "ق"),
    ("kaf", "ك"),
    ("lam", "ل"),
    ("meem", "م"),
    ("noon", "ن"),
    ("haa_h", "ه"),
    ("waw", "و"),
    ("yaa", "ي"),
    ("hamza_on_alif", "أ"),
    ("hamza_on_yaa", "ئ"),
    ("taa_marbuta", "ة"),
    ("laam_alif", "لا"),
]

# Create folders for each class if they don't exist
for translit, _ in labels:
    os.makedirs(os.path.join(DATA_DIR, translit), exist_ok=True)

# Open camera
cap = cv2.VideoCapture(camera_index)
if not cap.isOpened():
    raise RuntimeError("Cannot open camera")

def detect_hand_mask(frame):
    """
    Simple hand detection using YCrCb skin color thresholds.
    Returns (mask, max_contour_area).
    Recommended to replace with MediaPipe Hands for higher accuracy.
    """
    img_ycrcb = cv2.cvtColor(frame, cv2.COLOR_BGR2YCrCb)
    lower = np.array((0, 133, 77))
    upper = np.array((255, 173, 127))
    mask = cv2.inRange(img_ycrcb, lower, upper)
    mask = cv2.GaussianBlur(mask, (5,5), 0)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5,5))
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel, iterations=2)
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    max_area = max([cv2.contourArea(c) for c in contours], default=0)
    return mask, max_area

def add_text_space(frame, height=bottom_text_height):
    """
    Adds a black area at the bottom of the frame
    to display text and the small mask preview.
    """
    h, w = frame.shape[:2]
    canvas = np.zeros((h + height, w, 3), dtype=np.uint8)
    canvas[0:h, :] = frame
    return canvas

print("Controls: Q start | N skip | M toggle mirror | S skip mid-letter | ESC exit")

try:
    # Loop over each class
    for translit, arabic in labels:
        print(f"\nPreparing folder: {translit}  ({arabic})")
        folder = os.path.join(DATA_DIR, translit)

        # Determine starting index to avoid overwriting existing files
        existing = [f for f in os.listdir(folder) if f.lower().endswith(('.png','.jpg','.jpeg'))]
        start_idx = len(existing)
        print(f"Starting index for {translit}: {start_idx}  (existing files: {len(existing)})")

        # READY screen: show class name and wait for user action
        while True:
            ret, frame = cap.read()
            if not ret:
                break

            display_frame = frame if not mirror_preview else cv2.flip(frame, 1)
            disp = add_text_space(display_frame)
            base = display_frame.shape[0]

            cv2.putText(disp, f"Collect: {translit}   -   {arabic}", (20, base+38),
                        cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0,255,0), 2, cv2.LINE_AA)
            cv2.putText(disp, "Press 'q' to start | 'n' skip | 'm' toggle mirror", (20, base+78),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0,255,255), 1, cv2.LINE_AA)

            cv2.imshow("Ready", disp)
            key = cv2.waitKey(25) & 0xFF
            if key == ord('q'):
                break
            if key == ord('n'):
                break
            if key == ord('m'):
                mirror_preview = not mirror_preview
                print("Mirror preview:", mirror_preview)
                time.sleep(0.15)

        # Start capturing images
        counter = 0
        last_time = 0
        while counter < dataset_size:
            ret, frame = cap.read()
            if not ret:
                break

            # Apply mirror option
            proc_frame = frame if not mirror_preview else cv2.flip(frame, 1)
            disp = add_text_space(proc_frame)
            base = proc_frame.shape[0]

            # Hand detection on full frame
            mask, max_area = detect_hand_mask(proc_frame)
            mask_bgr = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)

            # Display text in the bottom area
            cv2.putText(disp, f"{translit} - {arabic}  ({start_idx + counter})", (20, base+38),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,255,0), 2, cv2.LINE_AA)
            cv2.putText(disp, f"Hand area: {int(max_area)}", (20, base+78),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,255,255), 1, cv2.LINE_AA)
            cv2.putText(disp, "ESC: exit  |  s: skip letter  |  m: toggle mirror",
                        (proc_frame.shape[1]-620, base+78),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (200,200,200), 1, cv2.LINE_AA)

            # Paste small mask preview in the bottom-right area
            small_mask = cv2.resize(mask_bgr, mask_preview_size)
            h0, w0 = proc_frame.shape[:2]
            disp[h0:h0+mask_preview_size[1], w0-mask_preview_size[0]:w0] = small_mask

            # Save condition: sufficient contour area + delay passed
            now = time.time()
            if max_area > min_contour_area and (now - last_time) >= delay_between_saves:
                save_img = cv2.resize(proc_frame, resize_to)
                filename = f"{start_idx + counter}.jpg"
                cv2.imwrite(os.path.join(folder, filename), save_img)
                counter += 1
                last_time = now

            cv2.imshow("Capture", disp)
            key = cv2.waitKey(1) & 0xFF
            if key == 27:  # ESC to exit completely
                raise KeyboardInterrupt
            if key == ord('s'):  # Skip current letter early
                print("Skipping this letter early.")
                break
            if key == ord('m'):
                mirror_preview = not mirror_preview
                print("Mirror preview:", mirror_preview)
                time.sleep(0.15)

        print(f"Finished {translit}. Saved {counter} new images "
              f"(from {start_idx} to {start_idx+counter-1}).")

    print("\nAll done. Releasing camera.")
finally:
    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# ---
# ---

# %% [markdown]
# # **Landmark Extraction & Dataset Generation**
#
# Purpose:
# This code processes hand gesture images and converts them into 3D hand landmarks using MediaPipe.
# It generates a structured CSV dataset with normalized relative coordinates suitable for machine learning models.

# %%
# ---------------- Optimized Settings ----------------
DATA_DIR = r"./data_32_letters"
OUT_CSV = r"../dataset/Sign_Language_dataset.csv"
MIN_DETECTION_CONF = 0.3
USE_RIGHT_HAND_ONLY = True
FLOAT_FORMAT = "%.12f"
TARGET_PER_LABEL = 100
RANDOM_SEED = 42
# ---------------------------------------------------

np.random.seed(RANDOM_SEED)
random.seed(RANDOM_SEED)

# Franco-to-Arabic label mapping (same previous list)
franco_to_ar = {
    "al": "ال", "alif": "أ", "ayn": "ع", "baa": "ب", "daad": "ض",
    "dal": "د", "dhal": "ذ", "faa": "ف", "ghayn": "غ", "haa": "ح",
    "haa_h": "ه", "hamza_on_yaa": "ئ", "jeem": "ج", "kaf": "ك",
    "khaa": "خ", "laam_alif": "لا", "lam": "ل", "meem": "م",
    "noon": "ن", "qaf": "ق", "raa": "ر", "saad": "ص", "seen": "س",
    "sheen": "ش", "taa": "ت", "taa_h": "ط", "taa_marbuta": "ة",
    "thaa": "ث", "waw": "و", "yaa": "ي", "zaa_h": "ظ", "zay": "ز"
}

ordered_letters = [
    "alif", "baa", "taa", "thaa", "jeem", "haa", "khaa",
    "dal", "dhal", "raa", "zay", "seen", "sheen", "saad",
    "daad", "taa_h", "zaa_h", "ayn", "ghayn", "faa", "qaf",
    "kaf", "lam", "meem", "noon", "haa_h", "waw", "yaa",
    "laam_alif", "al", "hamza_on_yaa", "taa_marbuta"
]

# --- Improvement 1: Add Z axis and clarify columns ---
# Columns layout:
# [x0_glob, y0_glob, z0_glob] -> wrist global reference (for visualization, not recommended for training)
# [x1_rel, y1_rel, z1_rel ... x20_rel, y20_rel, z20_rel] -> actual relative landmarks for training
cols = ["x0_glob", "y0_glob", "z0_glob"]
for i in range(1, 21):
    cols.append(f"x{i}")
    cols.append(f"y{i}")
    cols.append(f"z{i}")
cols.append("label")

# MediaPipe Hands initialization
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(
    static_image_mode=True,
    max_num_hands=2,
    min_detection_confidence=MIN_DETECTION_CONF
)

# Buffers
samples = {franco_to_ar.get(k, k): [] for k in ordered_letters}
missing = []

folders = [f for f in ordered_letters if os.path.isdir(os.path.join(DATA_DIR, f))]
print(f"Starting optimized processing with 3D Landmarks (X, Y, Z)...")

for folder_name in folders:
    folder_path = os.path.join(DATA_DIR, folder_name)
    arabic_label = franco_to_ar.get(folder_name, folder_name)

    img_files = sorted([
        f for f in os.listdir(folder_path)
        if f.lower().endswith(('.jpg', '.jpeg', '.png'))
    ])

    for img_name in tqdm(img_files, desc=f"{arabic_label}", unit="img"):
        img_path = os.path.join(folder_path, img_name)
        img = cv2.imread(img_path)
        if img is None:
            missing.append((folder_name, img_name, "read_error"))
            continue

        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        results = hands.process(img_rgb)

        if not results.multi_hand_landmarks:
            missing.append((folder_name, img_name, "no_hand"))
            continue

        # Hand selection logic (right hand only)
        chosen_idx = 0
        if USE_RIGHT_HAND_ONLY and results.multi_handedness:
            found_right = False
            for idx, handedness in enumerate(results.multi_handedness):
                if handedness.classification[0].label == "Right":
                    chosen_idx = idx
                    found_right = True
                    break
            if not found_right:
                missing.append((folder_name, img_name, "left_hand_ignored"))
                continue

        lm_list = results.multi_hand_landmarks[chosen_idx].landmark

        # --- Improvement 2: Extract X, Y, Z ---
        # Landmark 0 (wrist) is used as reference
        x0, y0, z0 = lm_list[0].x, lm_list[0].y, lm_list[0].z

        # Relative landmarks matrix (20, 3)
        pts_rel = np.zeros((20, 3), dtype=np.float32)

        for i in range(1, 21):
            pts_rel[i-1, 0] = lm_list[i].x - x0
            pts_rel[i-1, 1] = lm_list[i].y - y0
            pts_rel[i-1, 2] = lm_list[i].z - z0

        samples[arabic_label].append({
            "global": [x0, y0, z0],
            "pts_rel": pts_rel
        })

hands.close()

# --- Improvement 3: 3D Data Augmentation ---
def augment_landmarks_3d(pts_rel_20x3):
    """
    pts_rel_20x3: (20, 3) relative landmarks
    """
    pts = pts_rel_20x3.copy()

    # 1. Rotation around Z-axis (2D image rotation)
    angle_deg = np.random.uniform(-13, 13)
    theta = np.deg2rad(angle_deg)
    c, s = np.cos(theta), np.sin(theta)
    R = np.array([[c, -s], [s, c]], dtype=np.float32)
    pts[:, :2] = pts[:, :2].dot(R.T)

    # 2. Scale (applied to all dimensions)
    scale = np.random.uniform(0.90, 1.10)
    pts = pts * scale

    # 3. Gaussian noise (jitter)
    noise = np.random.normal(0, 0.002, pts.shape)
    pts = pts + noise

    return pts

print("\n--- Balancing Data (Augmentation/Sampling) ---")
out_rows = []

for label, arr_list in samples.items():
    n_exist = len(arr_list)
    if n_exist == 0:
        continue

    take_n = min(n_exist, TARGET_PER_LABEL)
    indices = np.random.choice(range(n_exist), size=take_n, replace=False)

    # Add real samples
    for idx in indices:
        s = arr_list[idx]
        flat_data = s["global"] + s["pts_rel"].flatten().tolist() + [label]
        out_rows.append(flat_data)

    # Generate augmented samples if needed
    needed = TARGET_PER_LABEL - take_n
    if needed > 0:
        added = 0
        tries = 0
        while added < needed and tries < needed * 50:
            tries += 1
            base_sample = random.choice(arr_list)
            aug_pts = augment_landmarks_3d(base_sample["pts_rel"])

            aug_global = [
                base_sample["global"][0] + np.random.normal(0, 0.01),
                base_sample["global"][1] + np.random.normal(0, 0.01),
                base_sample["global"][2]
            ]

            flat_data = aug_global + aug_pts.flatten().tolist() + [label]
            out_rows.append(flat_data)
            added += 1

    print(f"Label: {label} -> Original: {n_exist} -> Final: {TARGET_PER_LABEL}")

# Save final dataset
df_out = pd.DataFrame(out_rows, columns=cols)
df_out.to_csv(
    OUT_CSV,
    index=False,
    encoding="utf-8-sig",
    float_format=FLOAT_FORMAT
)

print("\nSaved optimized CSV:", OUT_CSV)
print("Final Shape:", df_out.shape)

if missing:
    pd.DataFrame(
        missing,
        columns=["Folder", "Image", "Reason"]
    ).to_csv("missing_log_v2.csv", index=False)
    print(f"Logged {len(missing)} missing/ignored images.")
